# %%
# %%capture
# workdir = '/notebooks'
workdir = '/mnt/f/Github'
speechbraindir = '/mnt/f/Github/speechbrain_Markandu'
#workdir = '/content'
# !pwd
# %cd $workdir
#!pip install --upgrade --no-cache-dir gdown
#!gdown https://drive.google.com/uc?id=1A38MiosJ3Ibv3Nnp6hN9f2Vz-Q-WSlEP
# !wget 'https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2'
# !tar xjvf LJSpeech-1.1.tar.bz2
# data_folder=workdir + '/LJSpeech-1.1/'

# from google.colab import drive
# drive.mount(workdir + '/drive')
# data_folder=workdir + '/drive/LJSpeech-1.1/'
# Out:
# /mnt/f/Github/speechbrain_Markandu/recipes/LJSpeech/TTS/tacotron2
# /mnt/f/Github

# %%
# %cd $workdir
#!rm -r ./speechbrain
# %%capture
# !git clone https://github.com/smarkandu/speechbrain.git
# Out:
# [Errno 2] No such file or directory: '/content'
# /mnt/f/Github/speechbrain_Markandu/steven
# Cloning into 'speechbrain'...
# remote: Enumerating objects: 79549, done.
# remote: Counting objects: 100% (2320/2320), done.
# remote: Compressing objects: 100% (1385/1385), done.
# remote: Total 79549 (delta 1189), reused 1464 (delta 860), pack-reused 77229
# Receiving objects: 100% (79549/79549), 86.94 MiB | 16.65 MiB/s, done.
# Resolving deltas: 100% (52969/52969), done.
# Updating files: 100% (1323/1323), done.

# %%
# !wget 'https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2'
# !tar xjvf LJSpeech-1.1.tar.bz2
data_folder=workdir + '/LJSpeech-1.1/'
# Out:
# Streaming output truncated to the last 5000 lines.
# LJSpeech-1.1/wavs/LJ022-0089.wav
# LJSpeech-1.1/wavs/LJ030-0192.wav
# LJSpeech-1.1/wavs/LJ041-0078.wav
# LJSpeech-1.1/wavs/LJ045-0249.wav
# LJSpeech-1.1/wavs/LJ034-0035.wav
# LJSpeech-1.1/wavs/LJ010-0152.wav
# LJSpeech-1.1/wavs/LJ036-0174.wav
# LJSpeech-1.1/wavs/LJ035-0076.wav
# LJSpeech-1.1/wavs/LJ032-0176.wav
# LJSpeech-1.1/wavs/LJ046-0113.wav
# LJSpeech-1.1/wavs/LJ017-0096.wav
# LJSpeech-1.1/wavs/LJ004-0098.wav
# LJSpeech-1.1/wavs/LJ010-0147.wav
# LJSpeech-1.1/wavs/LJ042-0230.wav
# LJSpeech-1.1/wavs/LJ041-0033.wav
# LJSpeech-1.1/wavs/LJ045-0229.wav
# LJSpeech-1.1/wavs/LJ014-0199.wav
# LJSpeech-1.1/wavs/LJ002-0082.wav
# LJSpeech-1.1/wavs/LJ006-0055.wav
# LJSpeech-1.1/wavs/LJ045-0120.wav
# LJSpeech-1.1/wavs/LJ050-0028.wav
# LJSpeech-1.1/wavs/LJ045-0215.wav
# LJSpeech-1.1/wavs/LJ013-0121.wav
# LJSpeech-1.1/wavs/LJ008-0025.wav
# LJSpeech-1.1/wavs/LJ005-0240.wav
# LJSpeech-1.1/wavs/LJ044-0026.wav
# LJSpeech-1.1/wavs/LJ048-0127.wav
# ...

# %%
# %%capture
# %cd $speechbraindir/recipes/LJSpeech/TTS
# !pip install -r extra_requirements.txt
# Out:
# /mnt/f/Github/speechbrain_Markandu/recipes/LJSpeech/TTS
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 48.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 48.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 50.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 KB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 KB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 KB 38.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 48.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 45.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %cd $speechbraindir
# !pip install -r requirements.txt
# !pip install .
# %cd ..
# Out:
# /mnt/f/Github/speechbrain_Markandu
# Defaulting to user installation because normal site-packages is not writeable
# Ignoring SoundFile: markers 'sys_platform == "win32"' don't match your environment
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Processing /mnt/f/Github/speechbrain_Markandu
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for speechbrain: filename=speechbrain-1.0.0-py3-none-any.whl size=765842 sha256=fc12213a704c90608f452688c9a99ce4772a061c4e1f836fea6ff728433829e5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w3khffn7/wheels/f0/13/7d/47a40c13ad731737f33777f19c769307b816a36adde8c8cf6c
# Successfully built speechbrain
# ...
#   Attempting uninstall: speechbrain
#     Found existing installation: speechbrain 1.0.0
#     Uninstalling speechbrain-1.0.0:
#       Successfully uninstalled speechbrain-1.0.0
# ...
# /mnt/f/Github

# %%
# data_folder = workdir + '/LJSpeech-1.1/'
# print(data_folder)
# %cd $workdir/speechbrain/recipes/LJSpeech/TTS/tacotron2
# #!ls -al $workdir/drive/MyDrive/LJSpeech-1.1/
# #!ls -al $workdir/LJSpeech-1.1/
# #!ls -al '/notebooks/LJSpeech-1.1/'
# !pwd
# !python train.py ./hparams/train.yaml --data_folder=$data_folder --batch_size=128

# %cd $workdir/speechbrain/recipes/Google-speech-commands
# !mkdir $workdir/GSC/train-synth
# !tar -xvf $workdir/GSC/speech_commands_v0.02.tar -C $workdir/GSC/train-synth
# !python train.py hparams/xvect.yaml --data_folder=$workdir/GSC
# Out:
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/xvect_v12/1986
# numexpr.utils - NumExpr defaulting to 8 threads.
# /content/GSC/noise/data.zip exists. Skipping download
# /content/GSC/rir/data.zip exists. Skipping download
# speechbrain.core - Exception:
# Traceback (most recent call last):
#   File "/content/speechbrain/recipes/Google-speech-commands/train.py", line 289, in <module>
#     train_data, valid_data, test_data, label_encoder = dataio_prep(hparams)
#   File "/content/speechbrain/recipes/Google-speech-commands/train.py", line 133, in dataio_prep
#     train_data = sb.dataio.dataset.DynamicItemDataset.from_csv(
#   File "/usr/local/lib/python3.10/dist-packages/speechbrain/dataio/dataset.py", line 408, in from_csv
#     data = load_data_csv(csv_path, replacements)
#   File "/usr/local/lib/python3.10/dist-packages/speechbrain/dataio/dataio.py", line 129, in load_data_csv
#     with open(csv_path, newline="") as csvfile:
# ...

# %%
# %cd $workdir
# # Create tar of results
# !tar -cjvf results.tar.gz ./results/
# !ls -al ./results.tar.gz
# # !tar -tf results.tar.gz
# #Copy into root of Google Drive
# !cp results.tar.gz $workdir/drive/MyDrive

# Copy results.tar from Google Drive and unzip into workdir
# !mv results results_old
# !cp $workdir/drive/MyDrive/results.tar.gz $workdir/results.tar.gz
# !tar xjvf results.tar.gz
# Out:
# /content

# %%
# %cd '/mnt/f/Github/speechbrain_Markandu/recipes/LJSpeech/TTS/tacotron2'
# !python3 train_transformer.py ./hparams/Transformer.yaml --device='cpu' --output_folder="/mnt/c/temp" --data_folder="/mnt/f/data/LJSpeech-1.1"
# Out:
# /mnt/f/Github/speechbrain_Markandu/recipes/LJSpeech/TTS/tacotron2
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# Traceback (most recent call last):
#   File "/mnt/f/Github/speechbrain_Markandu/recipes/LJSpeech/TTS/tacotron2/train_transformer.py", line 241, in <module>
#     hparams = load_hyperpyyaml(fin, overrides)
# ...
